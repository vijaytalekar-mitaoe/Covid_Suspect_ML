# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
corona_data = pd.ExcelFile(r"E:\V_I_J_A_Y\ML\vju\CORONA_SIR.xlsx")


shee_1 = pd.read_excel(r"E:\V_I_J_A_Y\ML\vju\CORONA_SIR.xlsx",sheetname=0)
print(sheetname=0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-e90fe778f33c> in <module>
# ----> 1 corona_data = pd.ExcelFile(r"E:\V_I_J_A_Y\ML\vju\CORONA_SIR.xlsx")
#       2
#       3
#       4 shee_1 = pd.read_excel(r"E:\V_I_J_A_Y\ML\vju\CORONA_SIR.xlsx",sheetname=0)
#       5 print(sheetname=0)
#
# c:\users\vijay\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# c:\users\vijay\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      18         """
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
# ...
